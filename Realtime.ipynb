# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)

# %%
pip install torchvision
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)

# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)

# %%
pip install ultralytics opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)

# %%
pip uninstall opencv-python opencv-python-headless -y
# Out:
# Found existing installation: opencv-python 4.10.0.84
# Uninstalling opencv-python-4.10.0.84:
#   Successfully uninstalled opencv-python-4.10.0.84
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Skipping opencv-python-headless as it is not installed.

# %%
pip install opencv-python
# Out:
# ...
#   Obtaining dependency information for opencv-python from https://files.pythonhosted.org/packages/ec/6c/fab8113424af5049f85717e8e527ca3773299a3c6b02506e66436e19874f/opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata
#   Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# WARNING: Ignoring invalid distribution ~pencv-python-headless (C:\Users\padma\AppData\Roaming\Python\Python311\site-packages)
# ...

# %%
import cv2
import torch
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO("best.pt")  # Replace with the correct model path

# Open the webcam
cap = cv2.VideoCapture(0)

# Check if the webcam opened successfully
if not cap.isOpened():
    print("Error: Could not access the webcam.")
    exit()

print("Webcam is running. Press 'q' to exit.")

try:
    while True:
        ret, frame = cap.read()
        if not ret:
            print("Error: Could not read frame from webcam.")
            break

        # Run YOLOv8 inference
        results = model(frame)  # Inference
        annotated_frame = results[0].plot()  # Annotate the frame with predictions

        try:
            # Try to display the frame using OpenCV
            cv2.imshow("YOLOv8 Dynamic Predictions", annotated_frame)

            # Exit if 'q' is pressed
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        except cv2.error as e:
            print("cv2.imshow failed. Falling back to matplotlib.")
            # Fall back to using Matplotlib if OpenCV fails
            plt.imshow(cv2.cvtColor(annotated_frame, cv2.COLOR_BGR2RGB))
            plt.axis('off')  # Hide axes
            plt.show(block=False)
            plt.pause(0.001)  # Give it a moment to render
            plt.clf()  # Clear the frame for the next iteration

except KeyboardInterrupt:
    print("Exiting...")

finally:
    # Release resources
    cap.release()
    cv2.destroyAllWindows()  # Close any OpenCV windows
    plt.close()  # Close any Matplotlib windows
    print("Webcam released, and windows closed.")
# Out:
# Webcam is running. Press 'q' to exit.
#
# 0: 480x640 (no detections), 477.5ms
# Speed: 20.7ms preprocess, 477.5ms inference, 15.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 394.4ms
# Speed: 7.0ms preprocess, 394.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 844.6ms
# Speed: 15.8ms preprocess, 844.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 575.7ms
# Speed: 27.9ms preprocess, 575.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 225.9ms
# Speed: 6.6ms preprocess, 225.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 217.3ms
# Speed: 10.7ms preprocess, 217.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 192.0ms
# ...
