# %% [markdown]
# <a href="https://colab.research.google.com/github/SravaniKarri137/Sign-Language-Detection-using-YOLOv8/blob/main/Signlanguage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 896.9/896.9 kB 22.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
from IPython.display import Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import gdown
# download the data from g drive

url = "https://drive.google.com/file/d/1CWSwE0hQOl05c1B9f2SM4j5cjohxZ6Fm/view?usp=sharing"
file_id = url.split("/")[-2]
print(file_id)

prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "sign_data1.zip")
# Out:
# 1CWSwE0hQOl05c1B9f2SM4j5cjohxZ6Fm
# Downloading...
# From: https://drive.google.com/uc?/export=download&id=1CWSwE0hQOl05c1B9f2SM4j5cjohxZ6Fm
# To: /content/sign_data1.zip
# 100%|██████████| 10.3M/10.3M [00:00<00:00, 34.1MB/s]
# 'sign_data1.zip'

# %%
# !unzip sign_data1.zip
# Out:
# Archive:  sign_data1.zip
#   inflating: data.yaml
#    creating: test/images/
#   inflating: test/images/Hello.82af5cd8-a6d1-11ec-a2fc-84a93ea18ae6.jpg
#   inflating: test/images/Hello.8b2540a6-a6d1-11ec-a828-84a93ea18ae6 - Copy.jpg
#   inflating: test/images/Hello.8b2540a6-a6d1-11ec-a828-84a93ea18ae6.jpg
#   inflating: test/images/Hello.8c5b98c8-a6d1-11ec-a905-84a93ea18ae6.jpg
#   inflating: test/images/Hello.8d922278-a6d1-11ec-9c17-84a93ea18ae6.jpg
#   inflating: test/images/IloveYou.01279dee-a6d2-11ec-a775-84a93ea18ae6.jpg
#   inflating: test/images/IloveYou.0391a1b8-a6d2-11ec-9246-84a93ea18ae6.jpg
#   inflating: test/images/IloveYou.04c7764c-a6d2-11ec-998a-84a93ea18ae6 - Copy.jpg
#   inflating: test/images/IloveYou.04c7764c-a6d2-11ec-998a-84a93ea18ae6.jpg
#   inflating: test/images/IloveYou.05fc3c80-a6d2-11ec-ba0a-84a93ea18ae6.jpg
#   inflating: test/images/No.b81769f8-a6d1-11ec-8d33-84a93ea18ae6.jpg
#   inflating: test/images/No.b94ba4ee-a6d1-11ec-b2ba-84a93ea18ae6.jpg
# ...

# %%
# !yolo task=detect mode=train data="/content/data.yaml" model="yolo11n.pt" epochs=50 imgsz=640
# Out:
# ...
# 100% 5.35M/5.35M [00:00<00:00, 92.4MB/s]
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image("/content/runs/detect/train/confusion_matrix.png", width=600)

# %%
Image("/content/runs/detect/train/labels.jpg", width=600)

# %%
Image("/content/runs/detect/train/results.png", width=600)

# %%
Image("/content/runs/detect/train/val_batch0_pred.jpg", width=600)

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train/weights/best.pt" conf=0.25 source="/content/test/images" save=True
# Out:
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,583,322 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/30 /content/test/images/Hello.82af5cd8-a6d1-11ec-a2fc-84a93ea18ae6.jpg: 480x640 1 Hello, 72.5ms
# image 2/30 /content/test/images/Hello.8b2540a6-a6d1-11ec-a828-84a93ea18ae6 - Copy.jpg: 480x640 1 Hello, 8.8ms
# image 3/30 /content/test/images/Hello.8b2540a6-a6d1-11ec-a828-84a93ea18ae6.jpg: 480x640 1 Hello, 8.6ms
# image 4/30 /content/test/images/Hello.8c5b98c8-a6d1-11ec-a905-84a93ea18ae6.jpg: 480x640 1 Hello, 9.3ms
# image 5/30 /content/test/images/Hello.8d922278-a6d1-11ec-9c17-84a93ea18ae6.jpg: 480x640 1 Hello, 7.9ms
# image 6/30 /content/test/images/IloveYou.01279dee-a6d2-11ec-a775-84a93ea18ae6.jpg: 480x640 1 IloveYou, 8.1ms
# image 7/30 /content/test/images/IloveYou.0391a1b8-a6d2-11ec-9246-84a93ea18ae6.jpg: 480x640 1 IloveYou, 9.6ms
# ...

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob('/content/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[1:4]:
    display(IPyImage(filename=img, width=600))
    print("\n")

# %%
# !yolo task=detect mode=predict model= "/content/runs/detect/train/weights/best.pt" conf=0.25 source="/content/test/images/WIN_20241202_16_32_06_Pro.jpg" save=True show=True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,583,322 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /content/test/images/WIN_20241202_16_32_06_Pro.jpg: 384x640 1 Hello, 67.8ms
# Speed: 8.6ms preprocess, 67.8ms inference, 873.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image, display
display(Image(filename='/content/runs/detect/predict6/WIN_20241202_16_32_06_Pro.jpg'))

# %%
# !yolo task=detect mode=predict model= "/content/runs/detect/train/weights/best.pt" conf=0.25 source="/content/test/images/WIN_20241202_16_38_55_Pro.jpg" save=True show=True
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics 8.3.39 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11n summary (fused): 238 layers, 2,583,322 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /content/test/images/WIN_20241202_16_38_55_Pro.jpg: 384x640 1 Please, 45.8ms
# Speed: 3.6ms preprocess, 45.8ms inference, 680.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict7
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image, display
display(Image(filename='/content/runs/detect/predict7/WIN_20241202_16_38_55_Pro.jpg'))
